# %%
"""
可以通过检查CybORG类中的变量active_agents来检查环境中哪些代理处于活动状态。
"""
from pprint import pp

from CybORG import CybORG
from CybORG.Simulator.Scenarios import EnterpriseScenarioGenerator
from  CybORG.Agents import SleepAgent,EnterpriseGreenAgent,FiniteStateRedAgent,BlueReactRemoveAgent

steps=20
sg=EnterpriseScenarioGenerator(
    blue_agent_class=SleepAgent,
    green_agent_class=EnterpriseGreenAgent,
    red_agent_class=FiniteStateRedAgent,
    steps=steps
                               )
cyborg=CybORG(scenario_generator=sg,seed=1234)
#环境初始化
cyborg.reset()

pp(cyborg.active_agents)
